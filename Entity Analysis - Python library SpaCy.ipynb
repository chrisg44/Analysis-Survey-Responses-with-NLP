# %% [markdown]
# # Entity Analysis - Python library SpaCy

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# # NLTK Example

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
from nltk import ne_chunk

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\chris\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\chris\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\chris\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
df = pd.read_csv('raw_data_short_text.csv', usecols=['Name a brand that really ‘gets you’ when it comes to their advertising.'])
df['Response'] = df['Name a brand that really ‘gets you’ when it comes to their advertising.']
df = df.drop(['Name a brand that really ‘gets you’ when it comes to their advertising.'], axis=1)

# %%
df.head()
# Out:
#           Response
# 0  There isn't one
# 1     Clarks shoes
# 2         Not sure
# 3             None
# 4             None

# %%
df = df.astype('str')

# %%
ex = 'President Donald Trump says US-China relations remain very strong despite the two countries being embroiled in a trade war. Mr Trump said talks between Washington and Beijing will continue even after a deadline passed on Friday for them to reach an agreement. As a result the US raised tariffs to 25% from 10% on goods from China.'

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(ex)
sent
# Out:
# [('European', 'JJ'),
#  ('authorities', 'NNS'),
#  ('fined', 'VBD'),
#  ('Google', 'NNP'),
#  ('a', 'DT'),
#  ('record', 'NN'),
#  ('$', '$'),
#  ('5.1', 'CD'),
#  ('billion', 'CD'),
#  ('on', 'IN'),
#  ('Wednesday', 'NNP'),
#  ('for', 'IN'),
#  ('abusing', 'VBG'),
#  ('its', 'PRP$'),
#  ('power', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('mobile', 'JJ'),
#  ('phone', 'NN'),
#  ('market', 'NN'),
#  ('and', 'CC'),
#  ('ordered', 'VBD'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ('to', 'TO'),
#  ('alter', 'VB'),
#  ('its', 'PRP$'),
#  ('practices', 'NNS')]

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'

# %%
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   European/JJ
#   authorities/NNS
#   fined/VBD
#   Google/NNP
#   (NP a/DT record/NN)
#   $/$
#   5.1/CD
#   billion/CD
#   on/IN
#   Wednesday/NNP
#   for/IN
#   abusing/VBG
#   its/PRP$
#   (NP power/NN)
#   in/IN
#   (NP the/DT mobile/JJ phone/NN)
#   (NP market/NN)
#   and/CC
#   ordered/VBD
#   (NP the/DT company/NN)
#   to/TO
#   alter/VB
#   its/PRP$
#   practices/NNS)

# %%
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('European', 'JJ', 'O'),
#  ('authorities', 'NNS', 'O'),
#  ('fined', 'VBD', 'O'),
#  ('Google', 'NNP', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('record', 'NN', 'I-NP'),
#  ('$', '$', 'O'),
#  ('5.1', 'CD', 'O'),
#  ('billion', 'CD', 'O'),
#  ('on', 'IN', 'O'),
#  ('Wednesday', 'NNP', 'O'),
#  ('for', 'IN', 'O'),
#  ('abusing', 'VBG', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('power', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('mobile', 'JJ', 'I-NP'),
#  ('phone', 'NN', 'I-NP'),
#  ('market', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('ordered', 'VBD', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('company', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('alter', 'VB', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('practices', 'NNS', 'O')]

# %%
ne_tree = ne_chunk(pos_tag(word_tokenize(ex)))
print(ne_tree)
# Out:
# (S
#   (GPE European/JJ)
#   authorities/NNS
#   fined/VBD
#   (PERSON Google/NNP)
#   a/DT
#   record/NN
#   $/$
#   5.1/CD
#   billion/CD
#   on/IN
#   Wednesday/NNP
#   for/IN
#   abusing/VBG
#   its/PRP$
#   power/NN
#   in/IN
#   the/DT
#   mobile/JJ
#   phone/NN
#   market/NN
#   and/CC
#   ordered/VBD
#   the/DT
#   company/NN
#   to/TO
#   alter/VB
#   its/PRP$
#   practices/NNS)

# %% [markdown]
# What are the different entity types?

# %% [markdown]
# https://www.ldc.upenn.edu/sites/www.ldc.upenn.edu/files/english-entities-guidelines-v5.6.6.pdf

# %%
chunker=nltk.data.load(nltk.chunk._MULTICLASS_NE_CHUNKER)
sorted(chunker._tagger._classifier.labels())
# Out:
# ['B-FACILITY',
#  'B-GPE',
#  'B-GSP',
#  'B-LOCATION',
#  'B-ORGANIZATION',
#  'B-PERSON',
#  'I-FACILITY',
#  'I-GPE',
#  'I-GSP',
#  'I-LOCATION',
#  'I-ORGANIZATION',
#  'I-PERSON',
#  'O']

# %% [markdown]
# # SpaCy Example

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
from spacy.tokens import Span

# %%
doc = nlp(ex)
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('Donald Trump', 'PERSON'),
#  ('US', 'GPE'),
#  ('China', 'GPE'),
#  ('two', 'CARDINAL'),
#  ('Mr Trump', 'PERSON'),
#  ('Washington', 'GPE'),
#  ('Beijing', 'GPE'),
#  ('Friday', 'DATE'),
#  ('US', 'GPE'),
#  ('25%', 'PERCENT'),
#  ('10%', 'PERCENT'),
#  ('China', 'GPE')]

# %%
displacy.render(nlp(ex), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Donald Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  says
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  relations remain very strong despite the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  countries being embroiled in a trade war.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Mr Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said talks between
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Beijing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will continue even after a deadline passed on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  for them to reach an agreement. As a result the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  raised tariffs to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     25%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     10%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  on goods from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div>

# %%
displacy.render(nlp(ex), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b1986543d65344a2bb701ae4130101f7-0" class="displacy" width="7010" height="617.0" direction="ltr" style="max-width: none; height: 617.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">President</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Donald</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">says</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">US-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">China</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">relations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">remain</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">strong</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">despite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">countries</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">being</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">embroiled</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">trade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">war.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Mr</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">said</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">talks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">between</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">Washington</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">Beijing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">continue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">even</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="365

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(ex) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('President', 'PROPN', 'President'),
#  ('Donald', 'PROPN', 'Donald'),
#  ('Trump', 'PROPN', 'Trump'),
#  ('says', 'VERB', 'say'),
#  ('China', 'PROPN', 'China'),
#  ('relations', 'NOUN', 'relation'),
#  ('remain', 'VERB', 'remain'),
#  ('strong', 'ADJ', 'strong'),
#  ('despite', 'ADP', 'despite'),
#  ('countries', 'NOUN', 'country'),
#  ('embroiled', 'VERB', 'embroil'),
#  ('trade', 'NOUN', 'trade'),
#  ('war', 'NOUN', 'war'),
#  ('Mr', 'PROPN', 'Mr'),
#  ('Trump', 'PROPN', 'Trump'),
#  ('said', 'VERB', 'say'),
#  ('talks', 'NOUN', 'talk'),
#  ('Washington', 'PROPN', 'Washington'),
#  ('Beijing', 'PROPN', 'Beijing'),
#  ('continue', 'VERB', 'continue'),
#  ('deadline', 'NOUN', 'deadline'),
#  ('passed', 'VERB', 'pass'),
#  ('Friday', 'PROPN', 'Friday'),
#  ('reach', 'VERB', 'reach'),
#  ('agreement', 'NOUN', 'agreement'),
#  ('result', 'NOUN', 'result'),
#  ('raised', 'VERB', 'raise'),
#  ('tariffs', 'NOUN', 'tariff'),
#  ('25', 'NUM', '25'),
#  ('%', 'NOUN', '%'),
#  ('10', 'NUM', '10'),
#  ('%', 'NOUN', '%'),
#  ('goods', 'NOUN', 'good'),
#  ('China', 'PROPN', 'China')]

# %%
df.head()
# Out:
#           Response
# 0  There isn't one
# 1     Clarks shoes
# 2         Not sure
# 3             None
# 4             None

# %%
entities = []
for i in tqdm(range(len(df['Response']))):
    doc = nlp(df['Response'][i])
    entities.append([(X.text, X.label_) for X in doc.ents])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 852/852 [00:13<00:00, 62.83it/s]

# %%
entity_list = []
for i in tqdm(range(len(entities))):
    for j in range(len(entities[i])):
        if entities[i][j][1] == 'ORG':
            entity_list.append(entities[i][j][0])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 852/852 [00:00<?, ?it/s]

# %%
entity_list
# Out:
# ['Lush Cosmetics',
#  'Cadbury',
#  'Tena',
#  'N/a',
#  'Marks',
#  'Yours Clothing',
#  'Yours Clothing',
#  'ASOS',
#  'Nike',
#  'England Sporting',
#  'ASOS',
#  'Pepsi',
#  'Gordon',
#  'Amazon',
#  'M &',
#  'MARKS',
#  'SPENCER',
#  'McMillan',
#  'Addidas',
#  'Marks',
#  'Addidas',
#  'Marks & Spencer',
#  'Marks',
#  'Hair',
#  'Marks',
#  'M&S',
#  'Marks & Spencer',
#  'Muller',
#  'Betty & Co',
#  'Rimmell',
#  'Nivea',
#  'M&S',
#  'ASOS',
#  'Gucci',
#  'Coca-Cola',
#  'Aerie',
#  'Tena',
#  'Aerie',
#  'Marks',
#  'Diet',
#  'Vogue',
#  'Marks',
#  'N/a',
#  "McDonald's",
#  'Tesco',
#  'RSPCA',
#  'Tesco',
#  'JOHN',
#  'M & S',
#  'Actimel',
#  'Nutrisse',
#  'Nike Miss Dior Channel']

# %%
'Garnier' in entity_list
# Out:
# False

# %%
df.loc[[18]]
# Out:
#    Response
# 18  Garnier

# %%
train_data = [
    ("Garnier", [(0, 7, 'ORG')])]

# %%
#optimizer = nlp.begin_training(get_data)
import random
from spacy.gold import GoldParse
for itn in tqdm(range(100)):
    random.shuffle(train_data)
    for raw_text, entity_offsets in train_data:
        doc = nlp.make_doc(raw_text)
        gold = GoldParse(doc, entities=entity_offsets)
        nlp.update([doc], [gold], drop=0.5)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:27<00:00,  3.55it/s]

# %%
entities2 = []
for i in tqdm(range(len(df['Response']))):
    doc = nlp(df['Response'][i])
    entities2.append([(X.text, X.label_) for X in doc.ents])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 852/852 [00:13<00:00, 65.23it/s]

# %%
entity_list2 = []
for i in tqdm(range(len(entities2))):
    for j in range(len(entities2[i])):
        if entities2[i][j][1] == 'ORG':
            entity_list2.append(entities2[i][j][0])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 852/852 [00:00<00:00, 170363.61it/s]

# %%
entity_list2
# Out:
# ['There',
#  'Clarks',
#  'None',
#  'None',
#  'Boots',
#  'None',
#  'Dior',
#  'h&m',
#  'Dove',
#  'Idk',
#  'Dove',
#  'campaigns',
#  'sizes',
#  'None',
#  'Dove',
#  "L'Oréal",
#  'None',
#  'Dove',
#  'Garnier',
#  'New',
#  "L'Oréal",
#  'Dove',
#  'New',
#  'Tampax',
#  'Venus',
#  'Primary',
#  'Lush',
#  'Dove',
#  'Always',
#  'Sure',
#  'Very',
#  'sizes',
#  'Nivea',
#  'Simply',
#  'Compare',
#  'market',
#  'Nescafe',
#  'None',
#  'Always',
#  'Unknown',
#  'George',
#  'None',
#  'Nobody',
#  'Dove',
#  'Always',
#  'Cadbury',
#  'Simply',
#  'Victories',
#  'Art',
#  'Any',
#  'Nike',
#  'Apple',
#  'Dove',
#  'Pantene',
#  'conditioner',
#  'Coop',
#  'Garnier',
#  'None',
#  'Natural',
#  'None',
#  'None',
#  'Dove',
#  'Venus',
#  'Dove',
#  'Always',
#  'Always',
#  'Boden',
#  'Loriel',
#  "L'0real",
#  'River',
#  'Ca',
#  'Most',
#  'me',
#  'Evans',
#  'Marks',
#  'Spencer',
#  'Nivea',
#  'Dove',
#  'Garnier',
#  'Tena',
#  'All',
#  'Cars',
#  'Persil',
#  'Chat',
#  'Simply',
#  'Always',
#  'Nivea',
#  'Lush',
#  'Dove',
#  'None',
#  'All',
#  'Coca',
#  'Dominos',
#  'Always',
#  'Dove',
#  'Always',
#  'Food',
#  'Loreal',
#  'None',
#  'Dove',
#  'N',
#  'ASCENO',
#  'Marks',
#  'Spencer',
#  "L'oreal",
#  'Gudrun',
#  'Sjodren',
#  'Next',
#  'Nike',
#  'Urban',
#  'Get',
#  'lynx',
#  'Simply',
#  'John',
#  'Wilkinsons',
#  'Killstar',
#  'Chocolate',
#  'Asos',
#  'Glossier',
#  'Dove',
#  'Missguided',
#  'Glasses',
#  'Clear',
#  'Simple',
#  'Nike',
#  'None',
#  'Dove',
#  'Always',
#  'Wallis',
#  'Chanel',
#  'Next',
#  'New',
#  'Ca',
#  'Innocent',
#  'Dove',
#  'None',
#  "L'Oréal",
#  'Dove',
#  'Next',
#  'Vw',
#  'None',
#  'Pregnancy',
#  'Yours',
#  'Clothing',
#  'Yours',
#  'Clothing',
#  'Dove',
#  'Kfc',
#  'Forever',
#  '21',
#  'Rockalily',
#  'Next',
#  'Sure',
#  'Always',
#  'B',
#  'None',
#  'Waterstones',
#  'Dove',
#  'New',
#  'Always',
#  'Dove',
#  ':-(',
#  'Pizzahut',
#  'Dove',
#  'way',
#  'Nike',
#  'Dove',
#  'Dove',
#  'None',
#  'Muller',
#  'Ca',
#  'Evans',
#  'None',
#  'None',
#  'ASOS',
#  'marks',
#  'models',
#  'hygiene',
#  'Zara',
#  'Dove',
#  'Ca',
#  'girl',
#  'can',
#  'Miss',
#  'Nike',
#  'Non',
#  'Mac',
#  'Simple',
#  'Sure',
#  'Always-',
#  'tampax',
#  'al',
#  'Oliver',
#  'bonas',
#  'Nivea',
#  'Tampax',
#  'Calvin',
#  'Dove',
#  'England Sporting',
#  'e.g.',
#  'Maybelline',
#  'Dove',
#  'Boohoo',
#  'na',
#  'M&S',
#  'Nescafé',
#  'Soap',
#  'Heinz',
#  'ASOS',
#  'Their',
#  'AA',
#  'Adidas',
#  'None',
#  'Skoda',
#  'Women',
#  'Gymshark',
#  'None',
#  'Steam',
#  'None',
#  'Colgate',
#  'overly',
#  'Aldi',
#  'Nike',
#  'There',
#  'my',
#  'Pepsi',
#  'Apple',
#  'me',
#  'ads',
#  'None',
#  'Dove',
#  'Ca',
#  'Ikea',
#  'Ikea',
#  'brand',
#  'Fresh',
#  'None',
#  'M&S',
#  'Nike',
#  'North',
#  'Le',
#  'Apple',
#  'Maybe',
#  'Nike',
#  'Words',
#  'World',
#  'John',
#  'Proactive',
#  'Nivea',
#  'Apple',
#  'Loreal',
#  'All',
#  'groups',
#  'Boots',
#  'Dolls',
#  'Disney',
#  'Special',
#  'Go',
#  'victoria',
#  'Topshop',
#  'Olay',
#  'Asda',
#  'Ariel',
#  'Maybelline',
#  'Dove',
#  'Asos',
#  'Dove',
#  'Clothing',
#  'general',
#  'Nike',
#  'Dove',
#  'digital',
#  'Body',
#  'Shop',
#  'Nike',
#  'Gordon',
#  'Gin',
#  'miss',
#  'Simple',
#  'Washing',
#  'Top',
#  'New',
#  'There',
#  'Sanctury',
#  'Wonder',
#  'Because',
#  'models',
#  'ASOS',
#  'Apple',
#  'Ca',
#  'None',
#  'Boots',
#  'Make',
#  'brands & fashion',
#  'brands',
#  'Dove',
#  'models',
#  'sizes',
#  'Coca',
#  'Amazon',
#  'M & s',
#  'Sleek',
#  'Probably',
#  'Dove',
#  'Household',
#  'sony',
#  'SCS',
#  'M&S',
#  'advert',
#  'River',
#  'simple',
#  'EVERYTHING',
#  'There',
#  'none',
#  'Aa',
#  'Any',
#  'brands',
#  'Waterstones',
#  'Any',
#  'none',
#  'Debenhams',
#  'MARKS',
#  'SPENCER',
#  'None',
#  'impericon',
#  'none',
#  'M&S',
#  'none',
#  'Dove',
#  'Compare',
#  'market',
#  'Nationwide',
#  'Dove',
#  'Boots',
#  'Marks',
#  'Spencer',
#  'Waitrose',
#  'Na',
#  'Always',
#  'towels',
#  'None',
#  'McMillan',
#  'john',
#  'ikea',
#  'dove',
#  'Bravissimo',
#  'FNF',
#  'Nationwide',
#  'Flash',
#  'product',
#  'manufacturers',
#  'coca',
#  "L'oreal",
#  'M&S',
#  'IKEA',
#  'None',
#  'Sure',
#  'Dove',
#  'Boots',
#  'Addidas',
#  'Primark',
#  'Body',
#  'form',
#  'Sure',
#  'Dove',
#  'advertising',
#  'Loreal',
#  'Apple',
#  'Tampax',
#  'Unsure',
#  "L'Oréal",
#  'Marks',
#  'spencer',
#  'Cadburys',
#  'Christmas',
#  'Dove',
#  'Topshop',
#  'Probably',
#  'Dove',
#  'L’Oréal',
#  'None',
#  'Addidas',
#  'Sketchers',
#  'Dove',
#  'Marks & Spencer',
#  "L'Oréal",
#  'Adidas',
#  'Loreal',
#  'Loreal',
#  'Asos',
#  'Fre',
#  'KAREN',
#  'MILLEN',
#  'Primary',
#  'H&M',
#  'Next',
#  'M&S',
#  'Nike',
#  'Garnier',
#  "L'Oréal",
#  'Tres',
#  'emme',
#  'Always',
#  'Marks',
#  'Dove',
#  'Dove',
#  'Miss',
#  'Selfridge',
#  'Boohoo',
#  'Nike',
#  'Sure',
#  'Levi',
#  'Tampax',
#  'Nike',
#  '120',
#  'Go',
#  'Compare',
#  'Hair',
#  'products',
#  'New',
#  'adidas',
#  'mac',
#  'Dove',
#  'Warehouse',
#  'Nike',
#  'Nike',
#  'Always',
#  'Adidas',
#  'Puma',
#  'Nivea',
#  'Nothing',
#  'Newlook',
#  'Compare',
#  'meerkat',
#  'Levi',
#  'Very.co.uk',
#  'Maxfactor',
#  'Boohoo',
#  'Always',
#  'Body',
#  'form',
#  'Boots',
#  'Boohoo.com',
#  'Sure',
#  'Always',
#  'Asda',
#  'Marks',
#  'spencer',
#  'Always',
#  'Dove',
#  'Dove',
#  'Bodyform',
#  'Deodorant',
#  'Next',
#  'Mr',
#  'Sure',
#  'Dove',
#  'Tampons',
#  'Next',
#  'None',
#  'Garnier',
#  'Na',
#  'Dove',
#  "L'oreal",
#  'Nike',
#  'Dove',
#  'Dove',
#  'Dove',
#  'Dior',
#  'Olay',
#  'Nike',
#  'Dove',
#  'Marks',
#  'Spencer',
#  'Good',
#  'M&S',
#  'me',
#  'brands',
#  'Dove',
#  "L'Oréal",
#  'Marks & Spencer',
#  'achieve',
#  'Maybeline',
#  'Dove',
#  'Muller',
#  'Carlsberg',
#  'Very',
#  'John',
#  'Boots',
#  'Olia',
#  'M&s',
#  'Adidas',
#  '-',
#  'Nike',
#  'Dove',
#  'Adidas',
#  'Maybaleen',
#  'Boohoo',
#  'Apple',
#  'Aaiko',
#  'Asda',
#  'Nivia',
#  'Impulse',
#  'Dk',
#  'Dove',
#  'Nike',
#  'Dove',
#  'Pretty',
#  'thing',
#  'AllSaints',
#  'After',
#  'Eden',
#  'Boohoo',
#  'Anita',
#  'Anecdote',
#  'Elemis',
#  'Always',
#  'Bergans',
#  'Bench',
#  'Adidas',
#  'Always',
#  'Amoralia',
#  'Anita',
#  'Dove',
#  'girl',
#  'can',
#  'ASICS',
#  'Nivea',
#  'Barbour',
#  'Edgy',
#  'Adidas',
#  'Nike',
#  'Betty & Co',
#  'Nike',
#  'bellybutton',
#  'Next',
#  'Sure',
#  'Bench',
#  'Non',
#  'Cfa',
#  'Bergans',
#  'Bardot',
#  'Adidas',
#  'Nivea',
#  'Dior',
#  "L'Oréal",
#  'Great',
#  'M&S',
#  'Nice',
#  'Aegos',
#  'Vft',
#  'dove',
#  'New',
#  'Adidas',
#  'Ca',
#  'Nike',
#  'BOOHOO.COM',
#  'Computers',
#  'girl',
#  'can',
#  'Rimmell',
#  'Boo',
#  'Body',
#  'Nivea',
#  'different',
#  'tones',
#  'Boss',
#  'Nike',
#  'Boots',
#  'Matalan',
#  'Next',
#  'Dove',
#  'Andrex',
#  'Gym',
#  'Any',
#  "L'oreal",
#  'Nike',
#  'B',
#  'Sure',
#  'Boohoo',
#  'dior',
#  'Evans',
#  'Tena',
#  'Chocolate',
#  'Victoria',
#  'Benefit',
#  'Loreal',
#  'girl',
#  'can',
#  'Maybelline',
#  'Gap',
#  'Next',
#  'Car',
#  'Boot',
#  'Dk',
#  'Soft',
#  'gentle',
#  'Sky',
#  'Dove',
#  'Fat',
#  'Muller',
#  'Dove',
#  'Malteasers',
#  'Next',
#  'Garnier',
#  'Dove',
#  'Unsure',
#  'Dove',
#  'Next',
#  'always',
#  'Vogue',
#  'Dior',
#  'Zara',
#  "L'Oréal",
#  'Nike',
#  'Nivea',
#  'Dove',
#  'Sure',
#  'Bodyform',
#  'Topshop',
#  'Next',
#  'nan',
#  'M&S',
#  'ASOS',
#  'Dove',
#  'Avon',
#  'Dior',
#  'Gucci',
#  'Always',
#  'Phase',
#  '8',
#  'River',
#  'Which',
#  'Ca',
#  'New',
#  'Look',
#  'Batiste',
#  'Dove',
#  'Always',
#  'Tampax',
#  'Nike',
#  'Coca',
#  'Mslteasers',
#  'Good',
#  'Boots',
#  'Sure',
#  'N\\a',
#  'Nivea',
#  'Fitbit',
#  'Always',
#  'Sure',
#  'Venus',
#  'Aerie',
#  'fashion',
#  'nova',
#  'Tena',
#  'Sainsbury',
#  'La',
#  'Missguided',
#  'Nike',
#  'VIPoo',
#  'M',
#  'Primary',
#  'opinion',
#  'advertising',
#  'products',
#  'Topshop',
#  'Doge',
#  'Tampax',
#  'Apple',
#  'Lush',
#  'Aldi',
#  'K',
#  "L'Oréal",
#  'Dove',
#  'Simply',
#  'Women',
#  'Tampax',
#  'Always',
#  'Nothing',
#  'sized',
#  'types',
#  'Aerie',
#  'Dkny',
#  'Superdry',
#  'Aj',
#  'nan',
#  'E45',
#  'Adidas',
#  'Clinque',
#  'Bourjois',
#  'Nivea',
#  'Victoria',
#  'Venus',
#  'John',
#  'Pampers',
#  'Lee',
#  'Anything',
#  'Apple',
#  'Simply',
#  'Sure',
#  'Simply',
#  'Always',
#  'Primark',
#  "L'Oréal",
#  'Deodorant',
#  'covet',
#  'marks',
#  'Dove',
#  'none',
#  'Channell',
#  'Nike',
#  'Nivea',
#  'M&s',
#  'Max',
#  'Olay',
#  'Nike',
#  'M&s',
#  'Dove',
#  'Dove',
#  'Marks',
#  'spencer',
#  'Lloyds',
#  "L'Oréal",
#  'Tampax',
#  'Nike',
#  'Newlook',
#  'Dogs',
#  'Dove',
#  'Nike',
#  'Loreal',
#  'New',
#  'Simple',
#  'New',
#  'Loreal',
#  'Topshop',
#  'All',
#  'them',
#  'Zara',
#  'Dove',
#  'Rimmel',
#  'M&S',
#  'EE',
#  'Kotex',
#  'Diet',
#  'coke',
#  'Nivea',
#  'Wellwoman',
#  'Dove',
#  'Digestive',
#  'Nike',
#  'Body',
#  'form',
#  'Cover',
#  'Venus',
#  'Always',
#  'Dove',
#  'Always',
#  'towels',
#  'New',
#  'Nike',
#  'Good',
#  'Garnier',
#  'Michael',
#  'Nothing',
#  'Vogue',
#  'Zara',
#  "L'Oréal",
#  'Sure',
#  'Zara',
#  'tesco',
#  'New',
#  'Loreal',
#  'Always',
#  'Always',
#  'Rimmel',
#  'Radley',
#  'Venus',
#  "L'oreal",
#  'Vogue',
#  'Dove',
#  'Dacia',
#  'Dove',
#  'Sainsbury',
#  'Very',
#  'Boohoo',
#  'Aveeno',
#  'Next',
#  'Loreal',
#  'Hellmens',
#  "L'Oréal",
#  'Clarins',
#  'Marks',
#  'spencer',
#  'None',
#  'N',
#  'Dove',
#  'Boots',
#  'Dove',
#  'EE',
#  'Next',
#  'Hnm',
#  'McDonald',
#  'Dove',
#  'Dove',
#  'adverts',
#  'Fcuk',
#  'Nike',
#  'Maltesers',
#  'Nike',
#  "L'oreal",
#  'Next',
#  'Holister',
#  'Next',
#  'Tesco',
#  'Skinny',
#  'M&S',
#  'Next',
#  'Too',
#  'Loreal',
#  'Nike',
#  'Punky',
#  'None',
#  'Boots',
#  'catchy',
#  'everyone',
#  'Dove',
#  'Gap',
#  'Primark',
#  'Mooncup',
#  'Dove',
#  'Evian',
#  'Perfume',
#  'ads',
#  'None',
#  'M&S',
#  'Clairol',
#  'Always',
#  'specsavers',
#  'Cocoa',
#  'Tena',
#  'RSPCA',
#  'Animals',
#  'next',
#  'M&S',
#  'next',
#  'Very',
#  'M&S',
#  'Dove',
#  'Gender',
#  "L'Oréal",
#  'Chanel',
#  'Loreal',
#  'Loreal',
#  'carefree',
#  'Dove',
#  'Mabelline',
#  'Woman',
#  'M&s',
#  'Sainsbury',
#  'Boots',
#  'Dove',
#  'COMPARE',
#  'THE',
#  'MARKET',
#  'Chanelle',
#  'Dk',
#  'Primark',
#  'none',
#  'none',
#  'Tesco',
#  'family',
#  'LE',
#  'OROAL',
#  'marks',
#  'JOHN',
#  'LEWIS',
#  'Boots.-',
#  'M & S',
#  'Nic',
#  'easy',
#  'next',
#  'Number',
#  '7',
#  'Platex',
#  'Next',
#  'Marks',
#  'Spencer',
#  'Actimel',
#  'Nutrisse',
#  'Perfume',
#  'next',
#  'Next',
#  'Go',
#  'Compare',
#  'ads',
#  'Nike']

# %%
'Garnier' in entity_list2
# Out:
# True

# %%
pd.DataFrame(entity_list2)[0].value_counts()[:10]
# Out:
# Dove       84
# Nike       37
# None       33
# Always     29
# Next       20
# L'Oréal    15
# Sure       15
# Nivea      14
# M&S        14
# Loreal     13
# Name: 0, dtype: int64
